# %%
import pandas as pd
import numpy as na
import matplotlib.pyplot as plt
import seaborn as snc

# %%
df1 = pd.read_csv(r"C:\Users\welcome\Pictures\Camera Roll\air-quality-india.csv")

# %%
df1
# Out:
#                  Timestamp  Year  Month  Day  Hour   PM2.5
# 0      2017-11-07 12:00:00  2017     11    7    12   64.51
# 1      2017-11-07 13:00:00  2017     11    7    13   69.95
# 2      2017-11-07 14:00:00  2017     11    7    14   92.79
# 3      2017-11-07 15:00:00  2017     11    7    15  109.66
# 4      2017-11-07 16:00:00  2017     11    7    16  116.50
# ...                    ...   ...    ...  ...   ...     ...
# 36187  2022-06-04 11:00:00  2022      6    4    11   35.89
# 36188  2022-06-04 12:00:00  2022      6    4    12   33.83
# 36189  2022-06-04 13:00:00  2022      6    4    13   33.05
# 36190  2022-06-04 14:00:00  2022      6    4    14   35.29
# 36191  2022-06-04 15:00:00  2022      6    4    15   40.67
#
# [36192 rows x 6 columns]

# %%
year_2017_data = df1[(df1['Year'] == 2022) & (df1['Month'] ==7)]

# Calculate the sum of the "pm 22.5" column for the filtered data
sum_pm_22_5 = year_2017_data['PM2.5'].mean()

# Print the result
print(f"Sum of 'pm 2.5' for the year 2017 and month {7}: {sum_pm_22_5}")
# Out:
# Sum of 'pm 2.5' for the year 2017 and month 7: nan

# %%
df2 = pd.read_csv(r"C:\Users\welcome\Pictures\Camera Roll\Rainfall_ air quality_Timeseries.csv")

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of     month  year country_na  rainfall_mean  PM2.5_mean
# 0      11  2017      India      20.006818   97.713945
# 1      12  2017      India       9.438485   93.203757
# 2       1  2018      India       8.408765   94.057636
# 3       2  2018      India      13.532718   72.531757
# 4       3  2018      India      17.005894   64.846855
# 5       4  2018      India      35.041269   53.167152
# 6       5  2018      India      69.600253   42.868204
# 7       6  2018      India     177.676253   26.154884
# 8       7  2018      India     312.770141   30.316574
# 9       8  2018      India     283.433991   56.319222
# 10      9  2018      India     138.074061   76.421659
# 11     10  2018      India      47.924474   82.782523
# 12     11  2018      India      18.027224   84.319392
# 13     12  2018      India      10.607873   61.953638
# 14      1  2019      India      15.016949   50.699781
# 15      2  2019      India      24.495192   43.689677
# ...

# %%
plt.scatter(df2['rainfall_mean'], df2['PM2.5_mean'],c=df2['month'], cmap='viridis')
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title('Relationship between PM2.5 Mean and Rainfall Mean')
plt.colorbar(label='Month')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame with columns 'rainfall_mean', 'PM2.5_mean', 'month', and 'year'
desired_year = 2018
filtered_df = df2[df2['year'] == desired_year]

plt.scatter(filtered_df['rainfall_mean'], filtered_df['PM2.5_mean'], c=filtered_df['month'], cmap='viridis')
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title(f'Relationship between PM2.5 Mean and Rainfall Mean for {desired_year}')
plt.colorbar(label='Month')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame with columns 'rainfall_mean', 'PM2.5_mean', 'month', and 'year'
desired_year = 2019
filtered_df = df2[df2['year'] == desired_year]

plt.scatter(filtered_df['rainfall_mean'], filtered_df['PM2.5_mean'], c=filtered_df['month'], cmap='viridis')
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title(f'Relationship between PM2.5 Mean and Rainfall Mean for {desired_year}')
plt.colorbar(label='Month')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame with columns 'rainfall_mean', 'PM2.5_mean', 'month', and 'year'
desired_year = 2020
filtered_df = df2[df2['year'] == desired_year]

plt.scatter(filtered_df['rainfall_mean'], filtered_df['PM2.5_mean'], c=filtered_df['month'], cmap='viridis')
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title(f'Relationship between PM2.5 Mean and Rainfall Mean for {desired_year}')
plt.colorbar(label='Month')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame with columns 'rainfall_mean', 'PM2.5_mean', 'month', and 'year'
desired_year = 2021
filtered_df = df2[df2['year'] == desired_year]

plt.scatter(filtered_df['rainfall_mean'], filtered_df['PM2.5_mean'], c=filtered_df['month'], cmap='viridis')
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title(f'Relationship between PM2.5 Mean and Rainfall Mean for {desired_year}')
plt.colorbar(label='Month')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df2 is your DataFrame with columns 'rainfall_mean', 'PM2.5_mean', 'month', and 'year'
desired_year = 2022
filtered_df = df2[df2['year'] == desired_year]

plt.scatter(filtered_df['rainfall_mean'], filtered_df['PM2.5_mean'], c=filtered_df['month'], cmap='viridis')
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title(f'Relationship between PM2.5 Mean and Rainfall Mean for {desired_year}')
plt.colorbar(label='Month')
plt.show()

# %%
plt.plot(df2['rainfall_mean'], df2['PM2.5_mean'])
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title('Relationship between PM2.5 Mean and Rainfall Mean')
plt.show()

# %%
snc.jointplot(x='rainfall_mean', y='PM2.5_mean', data=df2, kind='scatter')
plt.show()

# %%
plt.hexbin(df2['rainfall_mean'], df2['PM2.5_mean'], gridsize=20, cmap='Blues')
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title('Relationship between PM2.5 Mean and Rainfall Mean')
plt.colorbar(label='Count')
plt.show()

# %%
snc.lineplot(x='month', y='PM2.5_mean', data=df2, ci='sd')
plt.xlabel('Month')
plt.ylabel('PM2.5 Mean')
plt.title('Trend of PM2.5 Mean Over Time')
plt.show()
# Out:
# C:\Users\welcome\AppData\Local\Temp\ipykernel_10616\603800334.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   snc.lineplot(x='month', y='PM2.5_mean', data=df2, ci='sd')

# %%
snc.pairplot(df2, vars=['rainfall_mean', 'PM2.5_mean'], hue='month', palette='viridis')
plt.suptitle('Pair Plot of Rainfall Mean and PM2.5 Mean by Month')
plt.show()

# %%
# Correlation Heatmap:
# Visualize the correlation between different variables, including 'rainfall_mean' and 'PM2.5_mean', using a heatmap.
# python
# A positive or negative correlation between 'rainfall_mean' and 'PM2.5_mean' can give insights into their relationship.
correlation_matrix = df2[['rainfall_mean', 'PM2.5_mean']].corr()
snc.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Calculate the correlation matrix including 'month'
correlation_matrix = df2[['rainfall_mean', 'PM2.5_mean', 'month']].corr()

# Create a heatmap with annotations
snc.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Heatmap - Month Wise')
plt.show()

# %%
# Calculate the correlation matrix for each month
correlation_matrix_monthly = df2.groupby('month')[['rainfall_mean', 'PM2.5_mean']].corr().unstack()['rainfall_mean']

# Create a heatmap with annotations
snc.heatmap(correlation_matrix_monthly, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Heatmap: Rainfall Mean vs. PM2.5 Mean (Month-wise)')
plt.xlabel('Variable')
plt.ylabel('Month')
plt.show()

# %%
snc.regplot(x='rainfall_mean', y='PM2.5_mean', data=df2, scatter_kws={'s': 50}, line_kws={'color': 'red'})
plt.xlabel('Rainfall Mean')
plt.ylabel('PM2.5 Mean')
plt.title('Scatter Plot with Regression Line')
plt.show()

# %%
snc.boxplot(x=pd.cut(df2['rainfall_mean'], bins=5), y='PM2.5_mean', data=df2, palette='viridis')
plt.xlabel('Rainfall Mean (Binned)')
plt.ylabel('PM2.5 Mean')
plt.title('Conditional Box Plot')
plt.show()
# Out:
# C:\Users\welcome\AppData\Local\Temp\ipykernel_10616\425052508.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   snc.boxplot(x=pd.cut(df2['rainfall_mean'], bins=5), y='PM2.5_mean', data=df2, palette='viridis')
